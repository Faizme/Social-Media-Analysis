# %% [markdown]
# # Clean & Analyze Social Media

# %%
# !pip install pandas numpy matplotlib seaborn

# %%
# Import necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import random

# %%
# Step 1: Generate random tweet data
# Define a list of categories for social media data
categories = ['food', 'travel', 'fashion', 'fitness', 'music', 'culture', 'health']

# Generate random data
n = 500 # Number of entries
data = {
    'Date': pd.date_range(start='2021-01-01', periods=n),
    'Category': [random.choice(categories) for _ in range(n)],  
    'Likes': np.random.randint(0, 10000, size=n)  
}

# %%
# Step 2: Load data into a DataFrame
tweets_df = pd.DataFrame(data) # Create a DataFrame from the data dictionary

# Print the first few rows of the DataFrame to check the data
print(tweets_df.head())

# To get the count of each Categories
print(tweets_df['Category'].value_counts())
# Out:
#         Date Category  Likes
# 0 2021-01-01  culture   1189
# 1 2021-01-02    music   4186
# 2 2021-01-03     food   9591
# 3 2021-01-04  fitness   1422
# 4 2021-01-05   health   8041
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Date      500 non-null    datetime64[ns]
#  1   Category  500 non-null    object
#  2   Likes     500 non-null    int32
# dtypes: datetime64[ns](1), int32(1), object(1)
# memory usage: 9.9+ KB
# None
#                       Date        Likes
# count                  500   500.000000
# mean   2021-09-07 12:00:00  4959.002000
# min    2021-01-01 00:00:00    11.000000
# 25%    2021-05-05 18:00:00  2302.500000
# 50%    2021-09-07 12:00:00  5036.000000
# 75%    2022-01-10 06:00:00  7533.250000
# max    2022-05-15 00:00:00  9989.000000
# std                    NaN  2933.968391
# Category
# health     80
# ...

# %%
# Step 3: Clean the data
tweets_df.dropna(inplace=True) # Remove any rows with null values
tweets_df.drop_duplicates(inplace=True) # Remove duplicate entries
tweets_df['Date'] = pd.to_datetime(tweets_df['Date']) # Ensure 'Data' is in datetime format
tweets_df['Likes'] = tweets_df['Likes'].astype(int) # Convert 'Likes' to integer type


print(tweets_df.head())  # Print the first few rows of the cleaned data

print(tweets_df.info()) # Print a summary of the DataFrame
# Out:
#         Date Category  Likes
# 0 2021-01-01  culture   1189
# 1 2021-01-02    music   4186
# 2 2021-01-03     food   9591
# 3 2021-01-04  fitness   1422
# 4 2021-01-05   health   8041
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Date      500 non-null    datetime64[ns]
#  1   Category  500 non-null    object
#  2   Likes     500 non-null    int32
# dtypes: datetime64[ns](1), int32(1), object(1)
# memory usage: 9.9+ KB
# None

# %%
# Step 4: Data Visualization and Analysis

# 1. Histogram of Likes
plt.figure(figsize=(10, 5))
sns.histplot(tweets_df['Likes']) # Plot the distribution of Likes
plt.title('Distribution of Likes') # Add title to the histogram
plt.xlabel('Likes')
plt.ylabel('Frequency')
plt.show() # show the plot

# 2. Boxplot of Likes by Category
plt.figure(figsize=(12, 6))
sns.boxplot(x='Category', y='Likes', data=tweets_df) # Plot Likes distribution across categories
plt.title('Boxplot of Likes by Category') # Add title to the boxplot
plt.xlabel('Category')
plt.ylabel('Likes')
plt.xticks(rotation=45)
plt.show() # show the plot

# 3. Statistical Analysis
mean_likes = tweets_df['Likes'].mean() # Calculate the mean of Likes
print(f"Mean Likes: {mean_likes:.2f}") # Print the mean Likes

# Mean Likes by Category
mean_likes_by_category = tweets_df.groupby('Category')['Likes'].mean()
print("\nMean Likes by Category:")
print(mean_likes_by_category) # Print the mean Likes for each category
# Out:
# Mean Likes: 4959.00
#
# Mean Likes by Category:
# Category
# culture    4835.108108
# fashion    5054.648649
# fitness    4236.521127
# food       5013.105263
# health     5084.712500
# music      5036.639344
# travel     5497.781250
# Name: Likes, dtype: float64

# %% [markdown]
# ## Conclusion
# In this project, I successfully created and analyzed a synthetic social media dataset using Python libraries like Pandas, NumPy, Seaborn, and Matplotlib. The main goals were to generate random tweet data, clean it, analyze it, and visualize the results.
#
# #### **Process Overview**
# 1. Data Generation:
# - I generated random data for tweet interactions, including Date, Category, and Likes, using Pandas for dates, the random module for categories, and NumPy for likes.
#
# 2. Data Cleaning:
# - I cleaned the dataset by removing null values and duplicates and ensured the Date and Likes columns had the correct data types.
#
# 3. Data Analysis and Visualization:
# - I visualized the data with histograms and boxplots to understand patterns and outliers.
# - I calculated the mean number of Likes overall and by category, which provided insights into social media engagement.
#
# #### **Key Findings**
# - Likes Distribution: The histogram showed that most tweets received few Likes, while some had high engagement.
# - Category Performance: The boxplot helped identify which content categories, like Food and Travel, generated more engagement.
#
# #### **Challenges and Solutions**
# I faced challenges with data cleaning, especially ensuring there were no duplicates. I addressed this by using the right Pandas methods. I also worked on making the visualizations clear and effective through trial and error.
#
# #### **Project Distinctiveness**
# This project stands out due to its comprehensive approach, from data generation to analysis. The use of synthetic data allows for experimentation, and the insights gained are valuable for optimizing social media strategies.
#
# #### **Future Improvements**
# For future versions of this project, I would consider:
#
# - Using real Twitter data via APIs for more authentic insights.
# - Implementing advanced analytics, such as sentiment analysis.
# - Creating a user-friendly dashboard for easier data visualization.
#
# This project showcases my critical thinking and problem-solving skills, making it a strong addition to my portfolio. It reflects my ability to derive insights from data, which is essential in today’s data-driven world.
